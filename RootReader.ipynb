# %%
import root_pandas as rp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Welcome to JupyROOT 6.24/06

# %%
sig=rp.read_root('RootFiles/splitMC.root','SignalTest')

# %%
#Check Variables inside tree
for element in sig:
    k=k+1
    print(element)
print(k)
# Out:
# mll
# lead
# sublead
# weight
# 4

# %%
#Check elements of specific variable
rep=sig['mll']
for e in rep:
    print(e)
# Out:
# 80.52373504638672
# 92.44850158691406
# 91.70155334472656
# 90.01139831542969
# 95.68753814697266
# 88.20348358154297
# 90.70589447021484
# 89.83580017089844
# 89.54020690917969
# 90.36639404296875
# 93.46112060546875
# 86.24079132080078
# 79.42411804199219
# 81.45552825927734
# 85.63540649414062
# 90.18097686767578
# 89.19546508789062
# 88.56005096435547
# 82.91382598876953
# 93.953125
# 90.02833557128906
# 92.06370544433594
# 87.79907989501953
# 70.22128295898438
# 88.32557678222656
# 88.21735382080078
# 91.86734008789062
# 99.96429443359375
# 88.36892700195312
# 89.93712615966797
# 87.3992691040039
# 91.07913970947266
# 87.71696472167969
# 90.14771270751953
# 86.06497955322266
# 78.72649383544922
# 89.26669311523438
# 91.87006378173828
# 90.48745727539062
# 87.15879821777344
# 90.19792175292969
# 78.5953598022461
# 93.38717651367188
# 80.23992919921875
# 86.38504791259766
# 91.5248794555664
# 89.20005798339844
# 90.41812896728516
# 92.03451538085938
# 71.58963012695312
# ...
