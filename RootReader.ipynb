# %%
import root_pandas as rp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sig=rp.read_root('example.root','signal')

# %%
rep=sig['lead']
for element in rep:
    print(element)
# Out:
# 36.70953369140625
# 33.28866195678711
